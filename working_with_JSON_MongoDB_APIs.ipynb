# %% [markdown]
# # **Fetching JSON Data**

# %%
import pandas as pd
import requests
import json

# %%
url = 'https://storage.googleapis.com/kagglesdsdata/datasets/1108393/1862570/One%20Piece%20json.json?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240623%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240623T113514Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...'

# %%
response = requests.get(url)
json_data = response.json()

# %%
df = pd.json_normalize(json_data)

# %%
df.head()
# Out:
#    Unnamed: 0    rank trend  season  episode  \
# 0           0  24,129    18       1        1
# 1           1  29,290    11       1        2
# 2           2  32,043     7       1        3
# 3           3  28,818     8       1        4
# 4           4  37,113     4       1        5
#
#                                                 name  start total_votes  \
# 0  I'm Luffy! The Man Who Will Become the Pirate ...   1999         647
# 1  The Great Swordsman Appears! Pirate Hunter, Ro...   1999         473
# 2  Morgan vs. Luffy! Who's This Beautiful Young G...   1999         428
# 3       Luffy's Past! The Red-haired Shanks Appears!   1999         449
# 4  Fear, Mysterious Power! Pirate Clown Captain B...   1999         370
#
#    average_rating
# 0             7.6
# 1             7.8
# 2             7.7
# 3             8.1
# 4             7.5

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df
# Out:
#        rank trend  season  episode  \
# 0    24,129    18       1        1
# 1    29,290    11       1        2
# 2    32,043     7       1        3
# 3    28,818     8       1        4
# 4    37,113     4       1        5
# ..      ...   ...     ...      ...
# 953  41,448    26       1      954
# 954  35,342    44       1      955
# 955  33,715    75       1      956
# 956   2,940   964       1      957
# 957  14,751     -       1      958
#
#                                                   name  start total_votes  \
# 0    I'm Luffy! The Man Who Will Become the Pirate ...   1999         647
# 1    The Great Swordsman Appears! Pirate Hunter, Ro...   1999         473
# 2    Morgan vs. Luffy! Who's This Beautiful Young G...   1999         428
# 3         Luffy's Past! The Red-haired Shanks Appears!   1999         449
# 4    Fear, Mysterious Power! Pirate Clown Captain B...   1999         370
# ..                                                 ...    ...         ...
# ...

# %% [markdown]
# if the data is present in a file the use `pd.read_json(filepath)`
#
# also we can directly read it as below

# %%
df = pd.read_json('https://storage.googleapis.com/kagglesdsdata/datasets/1108393/1862570/One%20Piece%20json.json?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240623%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240623T113514Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...')

df.head()
# Out:
#    Unnamed: 0    rank trend  season  episode  \
# 0           0  24,129    18       1        1
# 1           1  29,290    11       1        2
# 2           2  32,043     7       1        3
# 3           3  28,818     8       1        4
# 4           4  37,113     4       1        5
#
#                                                 name  start total_votes  \
# 0  I'm Luffy! The Man Who Will Become the Pirate ...   1999         647
# 1  The Great Swordsman Appears! Pirate Hunter, Ro...   1999         473
# 2  Morgan vs. Luffy! Who's This Beautiful Young G...   1999         428
# 3       Luffy's Past! The Red-haired Shanks Appears!   1999         449
# 4  Fear, Mysterious Power! Pirate Clown Captain B...   1999         370
#
#    average_rating
# 0             7.6
# 1             7.8
# 2             7.7
# 3             8.1
# 4             7.5

# %% [markdown]
# # **MongoDB**

# %%
# !pip install pymongo dnspython
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 669.1/669.1 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 8.4 MB/s eta 0:00:00
# ...

# %%
import pymongo

# %%
mongo_uri = "mongodb_uri"

# %%
# Create a MongoDB client

client = pymongo.MongoClient(mongo_uri)

# %%
# Access database

db = client['database_name']


# Access the collection
collection = db['collection_name']

# %%
# Fetch data from the collection (into a list)

data = list(collection.find())

# %%
df = pd.DataFrame(data)

# %%
df.head()

# %% [markdown]
# # **API**

# %%
import requests
import json

# %%
response = requests.get("API KEY HERE!")

# %%
pd.DataFrame(response.json()['key name here'])
